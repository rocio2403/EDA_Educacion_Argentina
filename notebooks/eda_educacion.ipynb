# %% [markdown]
# # Análisis Exploratorio de Datos – Educación Argentina
#
# ## Objetivo
# El objetivo de este análisis es explorar y comprender datos educativos
# de Argentina, analizando la distribución de unidades educativas y la
# matrícula por distrito.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Carga de datos

# %%
distritos = pd.read_csv("../data/raw/distritos_escolares.csv")
unidades = pd.read_excel("../data/raw/unidades_educativas_2024.xlsx")
matriculados = pd.read_excel("../data/raw/matricula_2024.xlsx")

# %% [markdown]
# ## Exploración inicial de los datos

# %%
distritos.info()
unidades.info()
matriculados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21 entries, 0 to 20
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   id        21 non-null     int64
#  1   nombre    21 non-null     object
#  2   geometry  21 non-null     object
# dtypes: int64(1), object(2)
# memory usage: 636.0+ bytes
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19 entries, 0 to 18
# Data columns (total 5 columns):
#  #   Column                                                                          Non-Null Count  Dtype
# ---  ------                                                                          --------------  -----
#  0   Unidades educativas por sector de gestión según modalidad y nivel de enseñanza  7 non-null      object
#  1   Unnamed: 1                                                                      13 non-null     object
# ...
